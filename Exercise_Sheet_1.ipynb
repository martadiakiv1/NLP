# %% [markdown]
# # Natural Language Processing
#
# ## Exercise Sheet 1

# %%
#imports for all exercises
import nltk
from nltk.book import *
import matplotlib.pylab as plt

# %% [markdown]
# ### Exercise 1
#
# How many words are there in `text2` from `nltk.book`? How many distinct words are there? Calculate the lexical diversity.

# %% [markdown]
# How many words are there:

# %%
#variables declaration
words_num = len(text2)
distinct_words_num = len(set(text2))
lexical_diversity = len(set(text2)) / len(text2)

# %%
#print
print("Number of words:              ", words_num)
print("Number of distinct words:     ", distinct_words_num)
print("Lexical diversity:            ", lexical_diversity, "= ", lexical_diversity*100, "%")
# Out:
# Number of words:               141576
# Number of distinct words:      6833
# Lexical diversity:             0.04826383002768831 =  4.826383002768831 %

# %% [markdown]
# ### Exercise 2
#
# Produce a dispersion plot of the four main protagonists in Sense and Sensibility: Elinor, Marianne, Edward, and Willoughby. What can you observe about the different roles played by the males and females in this novel? Can you identify the couples?

# %%
plt.rcParams["figure.figsize"] = [15,5]
text2.dispersion_plot(["Elinor", "Marianne", "Edward", "Willoughby"])

# %% [markdown]
# After analysing this figure it becomes clear, that females (Elinor, Marianne) takes more volume of the novel than male figures. The dispersion plot has shown
# that we can meet these protagonists almost in every part of the book with little pauses. Whereas male figures are described in 3-4 relatively big parts of the
# text and they almost never appear to be together on the pages of the book.

# %% [markdown]
# ### Exercise 3
#
# Find the collocations in `text6`.

# %%
text6.collocations()
# Out:
# BLACK KNIGHT; clop clop; HEAD KNIGHT; mumble mumble; Holy Grail;
# squeak squeak; FRENCH GUARD; saw saw; Sir Robin; Run away; CARTOON
# CHARACTER; King Arthur; Iesu domine; Pie Iesu; DEAD PERSON; Round
# Table; clap clap; OLD MAN; dramatic chord; dona eis

# %% [markdown]
# ### Exercise 4
#
# Use only the `index()` function to find all the indexes of the word "sunset" in `text9`.

# %%
res = []
idx = 0
while True:
    try:
        #res.append(text9[ind:].index("sunset"))
        res.append(text9[idx:].index("sunset")+ idx)
        idx += 1      
    except:
        break
print(set(sorted(res)))
# Out:
# {64736, 642, 13381, 27014, 52092, 60857, 64721, 1650, 629, 13335, 1432, 16313, 49340, 60862}

# %% [markdown]
# ### Exercise 5
#
# What is the difference between the following two lines? Calculate the two values:
#
#     len(sorted(set(w.lower() for w in text1)))
#     len(sorted(w.lower() for w in set(text1)))

# %%
print(len(sorted(set(w.lower() for w in text1))))
print(len(sorted(w.lower() for w in set(text1))))
# Out:
# 17231
# 19317

# %% [markdown]
# The first line calculates the number of distinct  words regardless of their case in text1, whereas the second line calculates the number of any case words in the set of distinct words from the text1. Both lines present the result in sorted order. The second calculation gives us a bigger number, because we are treating words with different cases as different words. (E.g. "This" and "this")

# %% [markdown]
# ### Exercise 6
#
# Write the slice expression that extracts the last two words of `text2`.

# %%
text2[-2 :]
# Out:
# ['THE', 'END']

# %% [markdown]
# ### Exercise 7
#
# Find all the four-letter words in `text6`. With the help of a frequency distribution (`FreqDist`), show these words in decreasing order of frequency.

# %%
fdist = FreqDist(text6)
sorted([w for w in set(text6) if len(w) == 4], key = lambda w: -fdist[w])
# Out:
# ['that',
#  'your',
#  'What',
#  'this',
#  'HEAD',
#  'Well',
#  'have',
#  'boom',
#  'clop',
#  'with',
#  'away',
#  'here',
#  'Burn',
#  'what',
#  'King',
#  'Come',
#  'just',
#  'Holy',
#  'tell',
#  'Look',
#  'must',
#  'dead',
#  'That',
#  'will',
#  'from',
#  'they',
#  'come',
#  'very',
#  'name',
#  'know',
#  'Stop',
#  'were',
#  'into',
#  'clap',
#  'like',
#  'then',
#  'ZOOT',
#  'want',
#  'CART',
#  'them',
#  'more',
#  'Shut',
#  'sure',
#  'make',
#  'when',
#  'take',
#  'good',
#  'mean',
#  'room',
#  'land',
#  'much',
#  'didn',
#  'time',
#  'find',
#  'Just',
#  'Iesu',
#  'LEFT',
#  'rewr',
#  'back',
#  'king',
#  'seek',
#  'only',
#  'Zoot',
#  'Lord',
#  'thou',
#  'Hold',
#  'some',
#  'dona',
#  'Yeah',
#  'well',
#  'This',
#  'cave',
#  'said',
#  'Then',
#  'DEAD',
#  'thud',
#  'nice',
#  'They',
#  'does',
#  'hear',
#  'yeah',
#  'join',
#  'sing',
#  'down',
#  'Oooh',
#  'been',
#  'look',
#  'last',
#  'seen',
#  'word',
# ...

# %% [markdown]
# ### Exercise 8
#
# Create a set for the words in `text6`. Use a `for` and an `if` statement to loop over the words in the set and print all titlecased words with more than one character, one per line.

# %%
for w in set(text6):
    if len(w) > 1 and w.istitle():
        print(w, "\n")
# Out:
# Listen
#
# Bors
#
# Mind
#
# All
#
# Anarcho
#
# Aggh
#
# Prince
#
# Hoa
#
# Four
#
# So
#
# Bad
#
# Isn
#
# Those
#
# Do
#
# Ah
#
# Camaaaaaargue
#
# We
#
# Camelot
#
# Thou
#
# Quite
#
# Try
#
# Hee
#
# It
#
# Shut
#
# African
#
# Where
#
# Ives
#
# Brave
#
# Almighty
#
# Britons
#
# Could
#
# Who
#
# Thee
#
# Nine
#
# Aaauggh
#
# Morning
#
# Eh
#
# Oooo
#
# Agh
#
# Frank
#
# Skip
#
# Five
#
# Whoa
#
# Please
#
# Hmm
#
# Remove
#
# Quick
#
# Ninepence
#
# Un
#
# Concorde
#
# Um
#
# France
#
# Build
#
# Is
#
# Oooooooh
#
# Hyy
#
# Winter
#
# Winston
#
# Use
#
# Gawain
#
# Beast
#
# Pin
#
# Just
#
# Rather
#
# Peng
#
# Olfin
#
# Or
#
# Other
#
# Here
#
# Until
#
# Firstly
#
# Saint
#
# Auuuuuuuugh
#
# Nothing
#
# Peril
#
# Very
#
# Nay
#
# Oooohoohohooo
#
# Good
#
# Would
#
# Ask
#
# Yapping
#
# Oui
#
# She
#
# King
#
# Schools
#
# Huyah
#
# Will
#
# Assyria
#
# Woa
#
# First
#
# Aaaugh
#
# Iesu
#
# Exactly
#
# Aramaic
#
# Surely
#
# Off
#
# Erm
#
# My
#
# Halt
#
# Aauuugh
#
# Didn
# ...

# %% [markdown]
# ### Exercise 9
#
# Write expressions for finding all words in `text6` that meet the conditions listed below:
#
# a) ending in "ing",
#
# b) containing the letter "z",
#
# c) containing the letter sequence "pt".

# %%
print("a. einding in 'ing' ")
print([w for w in text6 if "ing" == w.lower()[-3: ]])
print([w for w in text6 if w.lower().endswith('ing')])
# Out:
# a. einding in 'ing'
# ...

# %%
print("b. containing letter 'z' ")
print([w for w in text6 if 'z' in w.lower()])
# Out:
# b. containing letter 'z'
# ['zone', 'amazes', 'Fetchez', 'Fetchez', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'Zoot', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'Zoot', 'Zoot', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'Zoot', 'Zoot', 'Zoot', 'Zoot', 'Zoot', 'Zoot', 'AMAZING', 'zoop', 'zoo', 'zhiv', 'frozen', 'zoosh']

# %%
print("c. containing the letter sequence 'pt' ")
print([w for w in text6 if 'pt' in w.lower()])
# Out:
# c. containing the letter sequence 'pt'
# ['empty', 'aptly', 'Thpppppt', 'Thppt', 'Thppt', 'empty', 'Thppppt', 'temptress', 'temptation', 'ptoo', 'Chapter', 'excepting', 'Thpppt']

# %% [markdown]
# ### Exercise 10
#
# Define `sent` to be the list of words `['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']`. Now write code to perform the following tasks:
#
# a) print all words beginning with "sh",
#
# b) print all words longer than four characters.

# %%
sent = ['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']

print("a. all words beginning with 'sh': ")
print([w for w in sent if w.startswith("sh")])

print("a. all words longer than four characters: ")
print([w for w in sent if len(w) > 4])
# Out:
# a. all words beginning with 'sh':
# ['she', 'shells', 'shore']
# a. all words longer than four characters:
# ['sells', 'shells', 'shore']

# %% [markdown]
# ### Exercise 11
#
# What does the following Python code do?
#
# `sum(len(w) for w in text1)`
#
# Can you use it to work out the average word length of `text1`?

# %% [markdown]
# This line of code sums up number of letters in each word in text1. Yes, we can use this code for finding the average word lenght. To do this we need to divide the calculated number by the number of words in text1

# %%
av_lenght = sum(len(w) for w in text1)/len(text1)
print("Average lenght: ", av_lenght)
# Out:
# Average lenght:  3.830411128023649

# %% [markdown]
# ### Exercise 12
#
# Define a function `freq(word, text)` that calculates how often a given word occurs in a text, not using `count()` but a `FreqDist`. Use the function to calculate how often "promise" appears in `text4`.

# %%
def freq(word, text):
    fdist = FreqDist(text);
    return fdist[word]

# %%
print(freq("promise", text4))
# Out:
# 52
